# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA, FactorAnalysis

# %%
allCbd = pd.read_pickle("Data/allCombined.pkl")

# %%
allCbd[[ 'sales_per_day_1875',
 'sales_per_day_1880',
 'sales_per_day_1885',
 'sales_per_day_1890',
 'sales_per_day_1895',
 'sales_per_day_1900',
 'sales_per_day_1901',
 'sales_per_day_1902',
 'sales_per_day_1903',
 'sales_per_day_1904',
 'sales_per_day_1905',
 'sales_per_day_1906',
 'sales_per_day_1907',
 'sales_per_day_1908',
 'sales_per_day_1909',
 'sales_per_day_1910',
 'sales_per_day_1911',
 'sales_per_day_1912',
 'sales_per_day_1913',
 'sales_per_day_1914',
 'sales_per_day_1915',
 'sales_per_day_1916',
 'sales_per_day_1917',
 'sales_per_day_1918',
 'sales_per_day_1919',
 'sales_per_day_1920',
 'sales_per_day_1921',
 'sales_per_day_1922',
 'sales_per_day_1923',
 'sales_per_day_1924',
 'sales_per_day_1925',
 'sales_per_day_1926',
 'sales_per_day_1927',
 'sales_per_day_1928',
 'sales_per_day_1929',
 'sales_per_day_1930',
 'sales_per_day_1931',
 'sales_per_day_1932',
 'sales_per_day_1933',
 'sales_per_day_1934',
 'sales_per_day_1935',
 'sales_per_day_1936',
 'sales_per_day_1937',
 'sales_per_day_1938',
 'sales_per_day_1939',
 'sales_per_day_1940',
 'sales_per_day_1941',
 'sales_per_day_1942',
 'sales_per_day_1943',
 'sales_per_day_1944',
 'sales_per_day_1945',
 'sales_per_day_1946',
 'sales_per_day_1947',
 'sales_per_day_1948',
 'sales_per_day_1949',
 'sales_per_day_1950',
 'sales_per_day_1951',
 'sales_per_day_1952',
 'sales_per_day_1953',
 'sales_per_day_1954',
 'sales_per_day_1955',
 'sales_per_day_1956',
 'sales_per_day_1957',
 'sales_per_day_1958',
 'sales_per_day_1959',
 'sales_per_day_1960',
 'sales_per_day_1961',
 'sales_per_day_1962',
 'sales_per_day_1963',
 'sales_per_day_1964',
 'sales_per_day_1965',
 'sales_per_day_1966',
 'sales_per_day_1967',
 'sales_per_day_1968',
 'sales_per_day_1969',
 'sales_per_day_1970',
 'sales_per_day_1971',
 'sales_per_day_1972',
 'sales_per_day_1973',
 'sales_per_day_1974',
 'sales_per_day_1975',
 'sales_per_day_1976',
 'sales_per_day_1977',
 'sales_per_day_1978',
 'sales_per_day_1979',
 'sales_per_day_1980',
 'sales_per_day_1981',
 'sales_per_day_1982',
 'sales_per_day_1983',
 'sales_per_day_1984',
 'sales_per_day_1985',
 'sales_per_day_1986',
 'sales_per_day_1987',
 'sales_per_day_1988',
 'sales_per_day_1989',
 'sales_per_day_1990',
 'sales_per_day_1991',
 'sales_per_day_1992',
 'sales_per_day_1993',
 'sales_per_day_1994',
 'sales_per_day_1995',
 'sales_per_day_1996',
 'sales_per_day_1997',
 'sales_per_day_1998',
 'sales_per_day_1999',
 'sales_per_day_2000',
 'sales_per_day_2001',
 'sales_per_day_2002',
 'sales_per_day_2003',
 'sales_per_day_2004',
 'sales_per_day_2005',
 'sales_per_day_2006',
 'sales_per_day_2007',
 'sales_per_day_2008',
 'sales_per_day_2009',
 'sales_per_day_2010',
 'sales_per_day_2011',
 'sales_per_day_2012',
 'sales_per_day_2013',
 'sales_per_day_2014',
 'sales_per_day_2015',
]].mean(axis=1,skipna=True).isnull().sum()
# Out:
# 138

# %%
allCbd.drop([ 'sales_per_day_1875',
 'sales_per_day_1880',
 'sales_per_day_1885',
 'sales_per_day_1890',
 'sales_per_day_1895',
 'sales_per_day_1900',
 'sales_per_day_1901',
 'sales_per_day_1902',
 'sales_per_day_1903',
 'sales_per_day_1904',
 'sales_per_day_1905',
 'sales_per_day_1906',
 'sales_per_day_1907',
 'sales_per_day_1908',
 'sales_per_day_1909',
 'sales_per_day_1910',
 'sales_per_day_1911',
 'sales_per_day_1912',
 'sales_per_day_1913',
 'sales_per_day_1914',
 'sales_per_day_1915',
 'sales_per_day_1916',
 'sales_per_day_1917',
 'sales_per_day_1918',
 'sales_per_day_1919',
 'sales_per_day_1920',
 'sales_per_day_1921',
 'sales_per_day_1922',
 'sales_per_day_1923',
 'sales_per_day_1924',
 'sales_per_day_1925',
 'sales_per_day_1926',
 'sales_per_day_1927',
 'sales_per_day_1928',
 'sales_per_day_1929',
 'sales_per_day_1930',
 'sales_per_day_1931',
 'sales_per_day_1932',
 'sales_per_day_1933',
 'sales_per_day_1934',
 'sales_per_day_1935',
 'sales_per_day_1936',
 'sales_per_day_1937',
 'sales_per_day_1938',
 'sales_per_day_1939',
 'sales_per_day_1940',
 'sales_per_day_1941',
 'sales_per_day_1942',
 'sales_per_day_1943',
 'sales_per_day_1944',
 'sales_per_day_1945',
 'sales_per_day_1946',
 'sales_per_day_1947',
 'sales_per_day_1948',
 'sales_per_day_1949',
 'sales_per_day_1950',
 'sales_per_day_1951',
 'sales_per_day_1952',
 'sales_per_day_1953',
 'sales_per_day_1954',
 'sales_per_day_1955',
 'sales_per_day_1956',
 'sales_per_day_1957',
 'sales_per_day_1958',
 'sales_per_day_1959',
 'sales_per_day_1960',
 'sales_per_day_1961',
 'sales_per_day_1962',
 'sales_per_day_1963',
 'sales_per_day_1964',
 'sales_per_day_1965',
 'sales_per_day_1966',
 'sales_per_day_1967',
 'sales_per_day_1968',
 'sales_per_day_1969',
 'sales_per_day_1970',
 'sales_per_day_1971',
 'sales_per_day_1972',
 'sales_per_day_1973',
 'sales_per_day_1974',
 'sales_per_day_1975',
 'sales_per_day_1976',
 'sales_per_day_1977',
 'sales_per_day_1978',
 'sales_per_day_1979',
 'sales_per_day_1980',
 'sales_per_day_1981',
 'sales_per_day_1982',
 'sales_per_day_1983',
 'sales_per_day_1984',
 'sales_per_day_1985',
 'sales_per_day_1986',
 'sales_per_day_1987',
 'sales_per_day_1988',
 'sales_per_day_1989',
 'sales_per_day_1990',
 'sales_per_day_1991',
 'sales_per_day_1992',
 'sales_per_day_1993',
 'sales_per_day_1994',
 'sales_per_day_1995',
 'sales_per_day_1996',
 'sales_per_day_1997',
 'sales_per_day_1998',
 'sales_per_day_1999',
 'sales_per_day_2000',
 'sales_per_day_2001',
 'sales_per_day_2002',
 'sales_per_day_2003',
 'sales_per_day_2004',
 'sales_per_day_2005',
 'sales_per_day_2006',
 'sales_per_day_2007',
 'sales_per_day_2008',
 'sales_per_day_2009',
 'sales_per_day_2010',
 'sales_per_day_2011',
 'sales_per_day_2012',
 'sales_per_day_2013',
 'sales_per_day_2014',
 'sales_per_day_2015',
],axis=1,inplace=True)

# %%
list(allCbd.columns)
# Out:
# ['Code',
#  'EnforceBansTobaccoAd_2007',
#  'EnforceBansTobaccoAd_2010',
#  'EnforceBansTobaccoAd_2012',
#  'EnforceBansTobaccoAd_2014',
#  'HelpToQuit_2007',
#  'HelpToQuit_2010',
#  'HelpToQuit_2012',
#  'HelpToQuit_2014',
#  'Both sexes_2000',
#  'Female_2000',
#  'Male_2000',
#  'Both sexes_2005',
#  'Female_2005',
#  'Male_2005',
#  'Both sexes_2010',
#  'Female_2010',
#  'Male_2010',
#  'Both sexes_2013',
#  'Female_2013',
#  'Male_2013',
#  'Both sexes_2014',
#  'Female_2014',
#  'Male_2014',
#  'Both sexes_2015',
#  'Female_2015',
#  'Male_2015',
#  'Both sexes_2016',
#  'Female_2016',
#  'Male_2016',
#  'Both sexes_2017',
#  'Female_2017',
#  'Male_2017',
#  'Both sexes_2018',
#  'Female_2018',
#  'Male_2018',
#  'MilUsd_1995',
#  'MilUsd_1996',
#  'MilUsd_1997',
#  'MilUsd_1998',
#  'MilUsd_1999',
#  'MilUsd_2000',
#  'MilUsd_2001',
#  'MilUsd_2002',
#  'MilUsd_2003',
#  'MilUsd_2004',
#  'MilUsd_2005',
#  'MilUsd_2006',
#  'MilUsd_2007',
#  'MilUsd_2008',
# ...

# %%
allCbd.loc[:,allCbd.isnull().sum()<80].isnull().sum().unique()
# Out:
# array([ 0,  6, 41,  1, 18,  2,  7, 73, 72], dtype=int64)

# %%
allCbd["AvgCigarettePriceDollars_Avg"] = allCbd[['AvgCigarettePriceDollars_2012',
 'AvgCigarettePriceDollars_2014']].mean(axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16368/633654718.py in <module>
# ----> 1 allCbd["AvgCigarettePriceDollars_Avg"] = allCbd[['AvgCigarettePriceDollars_2012',
#       2  'AvgCigarettePriceDollars_2014']].mean(axis=1)
#
# C:\ProgramData\Miniconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# C:\ProgramData\Miniconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
# ...

# %%
allCbd.drop(['AvgCigarettePriceDollars_2012',
 'AvgCigarettePriceDollars_2014'],axis=1,inplace=True)

# %%
allCbd["AvgTaxesAsPctCigarettePrice_Avg"] = allCbd[['AvgTaxesAsPctCigarettePrice_2012',
 'AvgTaxesAsPctCigarettePrice_2014']].mean(axis=1)

# %%
allCbd.drop(['AvgTaxesAsPctCigarettePrice_2012',
 'AvgTaxesAsPctCigarettePrice_2014'],axis=1,inplace=True)

# %%
list(allCbd.loc[:,allCbd.isnull().sum()>80].columns)
# Out:
# ['MilUsd_1995',
#  'MilUsd_1996',
#  'MilUsd_1997',
#  'MilUsd_1998',
#  'MilUsd_1999',
#  'MilUsd_2000',
#  'MilUsd_2001',
#  'MilUsd_2002',
#  'MilUsd_2003',
#  'MilUsd_2004',
#  'MilUsd_2005',
#  'MilUsd_2006',
#  'MilUsd_2007',
#  'MilUsd_2008',
#  'MilUsd_2009',
#  'MilUsd_2010',
#  'MilUsd_2011',
#  'MilUsd_2012',
#  'MilUsd_2013',
#  'MilUsd_2014',
#  'MilUsd_2015',
#  'MilUsd_2016',
#  'metricTons_metricTons_1995',
#  'metricTons_metricTons_1996',
#  'metricTons_metricTons_1997',
#  'metricTons_metricTons_1998',
#  'metricTons_metricTons_1999',
#  'metricTons_metricTons_2000',
#  'metricTons_metricTons_2001',
#  'metricTons_metricTons_2002',
#  'metricTons_metricTons_2003',
#  'metricTons_metricTons_2004',
#  'metricTons_metricTons_2005',
#  'metricTons_metricTons_2006',
#  'metricTons_metricTons_2007',
#  'metricTons_metricTons_2008',
#  'metricTons_metricTons_2009',
#  'metricTons_metricTons_2010',
#  'metricTons_metricTons_2011',
#  'metricTons_metricTons_2012',
# ...

# %%
allCbd[['MilUsd_1995',
 'MilUsd_1996',
 'MilUsd_1997',
 'MilUsd_1998',
 'MilUsd_1999',
 'MilUsd_2000',
 'MilUsd_2001',
 'MilUsd_2002',
 'MilUsd_2003',
 'MilUsd_2004',
 'MilUsd_2005',
 'MilUsd_2006',
 'MilUsd_2007',
 'MilUsd_2008',
 'MilUsd_2009',
 'MilUsd_2010',
 'MilUsd_2011',
 'MilUsd_2012',
 'MilUsd_2013',
 'MilUsd_2014',
 'MilUsd_2015',
 'MilUsd_2016']].mean(axis=1).isnull().sum()
# Out:
# 132

# %%
allCbd[['metricTons_metricTons_1995',
 'metricTons_metricTons_1996',
 'metricTons_metricTons_1997',
 'metricTons_metricTons_1998',
 'metricTons_metricTons_1999',
 'metricTons_metricTons_2000',
 'metricTons_metricTons_2001',
 'metricTons_metricTons_2002',
 'metricTons_metricTons_2003',
 'metricTons_metricTons_2004',
 'metricTons_metricTons_2005',
 'metricTons_metricTons_2006',
 'metricTons_metricTons_2007',
 'metricTons_metricTons_2008',
 'metricTons_metricTons_2009',
 'metricTons_metricTons_2010',
 'metricTons_metricTons_2011',
 'metricTons_metricTons_2012',
 'metricTons_metricTons_2013',
 'metricTons_metricTons_2014',
 'metricTons_metricTons_2015',
 'metricTons_metricTons_2016']].mean(axis=1).notnull().sum()
# Out:
# 73

# %%
allCbd[['metricTons_metricTons_1995',
 'metricTons_metricTons_1996',
 'metricTons_metricTons_1997',
 'metricTons_metricTons_1998',
 'metricTons_metricTons_1999',
 'metricTons_metricTons_2000',
 'metricTons_metricTons_2001',
 'metricTons_metricTons_2002',
 'metricTons_metricTons_2003',
 'metricTons_metricTons_2004',
 'metricTons_metricTons_2005',
 'metricTons_metricTons_2006',
 'metricTons_metricTons_2007',
 'metricTons_metricTons_2008',
 'metricTons_metricTons_2009',
 'metricTons_metricTons_2010',
 'metricTons_metricTons_2011',
 'metricTons_metricTons_2012',
 'metricTons_metricTons_2013',
 'metricTons_metricTons_2014',
 'metricTons_metricTons_2015',
 'metricTons_metricTons_2016']].mean(axis=1).isnull().sum()
# Out:
# 106

# %%
allCbd[['metricTons_metricTons_1995',
 'metricTons_metricTons_1996',
 'metricTons_metricTons_1997',
 'metricTons_metricTons_1998',
 'metricTons_metricTons_1999',
 'metricTons_metricTons_2000',
 'metricTons_metricTons_2001',
 'metricTons_metricTons_2002',
 'metricTons_metricTons_2003',
 'metricTons_metricTons_2004',
 'metricTons_metricTons_2005',
 'metricTons_metricTons_2006',
 'metricTons_metricTons_2007',
 'metricTons_metricTons_2008',
 'metricTons_metricTons_2009',
 'metricTons_metricTons_2010',
 'metricTons_metricTons_2011',
 'metricTons_metricTons_2012',
 'metricTons_metricTons_2013',
 'metricTons_metricTons_2014',
 'metricTons_metricTons_2015',
 'metricTons_metricTons_2016']].notnull().sum()
# Out:
# metricTons_metricTons_1995    39
# metricTons_metricTons_1996    37
# metricTons_metricTons_1997    40
# metricTons_metricTons_1998    41
# metricTons_metricTons_1999    41
# metricTons_metricTons_2000    42
# metricTons_metricTons_2001    40
# metricTons_metricTons_2002    41
# metricTons_metricTons_2003    43
# metricTons_metricTons_2004    45
# metricTons_metricTons_2005    42
# metricTons_metricTons_2006    39
# metricTons_metricTons_2007    35
# metricTons_metricTons_2008    30
# metricTons_metricTons_2009    29
# metricTons_metricTons_2010    24
# metricTons_metricTons_2011    24
# metricTons_metricTons_2012    24
# metricTons_metricTons_2013    27
# metricTons_metricTons_2014    28
# metricTons_metricTons_2015    27
# metricTons_metricTons_2016    32
# dtype: int64

# %%
fun = allCbd.loc[:,allCbd.isnull().sum()<80]

# %%
fun.columns
# Out:
# Index(['Code', 'EnforceBansTobaccoAd_2007', 'EnforceBansTobaccoAd_2010',
#        'EnforceBansTobaccoAd_2012', 'EnforceBansTobaccoAd_2014',
#        'HelpToQuit_2007', 'HelpToQuit_2010', 'HelpToQuit_2012',
#        'HelpToQuit_2014', 'Both sexes_2000', 'Female_2000', 'Male_2000',
#        'Both sexes_2005', 'Female_2005', 'Male_2005', 'Both sexes_2010',
#        'Female_2010', 'Male_2010', 'Both sexes_2013', 'Female_2013',
#        'Male_2013', 'Both sexes_2014', 'Female_2014', 'Male_2014',
#        'Both sexes_2015', 'Female_2015', 'Male_2015', 'Both sexes_2016',
#        'Female_2016', 'Male_2016', 'Both sexes_2017', 'Female_2017',
#        'Male_2017', 'Both sexes_2018', 'Female_2018', 'Male_2018',
#        'deathRate_1990', 'deathRate_1991', 'deathRate_1992', 'deathRate_1993',
#        'deathRate_1994', 'deathRate_1995', 'deathRate_1996', 'deathRate_1997',
#        'deathRate_1998', 'deathRate_1999', 'deathRate_2000', 'deathRate_2001',
# ...

# %%
fun = fun.drop(['deathRate_1990', 'deathRate_1991', 'deathRate_1992', 'deathRate_1993',
       'deathRate_1994', 'deathRate_1995', 'deathRate_1996', 'deathRate_1997',
       'deathRate_1998', 'deathRate_1999', 'deathRate_2000', 'deathRate_2001',
       'deathRate_2002', 'deathRate_2003', 'deathRate_2004', 'deathRate_2005',
       'deathRate_2006', 'deathRate_2007', 'deathRate_2008', 'deathRate_2009',
       'deathRate_2010', 'deathRate_2011', 'deathRate_2012', 'deathRate_2013',
       'deathRate_2014', 'deathRate_2015', 'deathRate_2016', 'deathRate_2017'],axis=1)

# %%
funDR = fun.drop(['Both sexes_2000', 'Female_2000', 'Male_2000',
       'Both sexes_2005', 'Female_2005', 'Male_2005', 'Both sexes_2010',
       'Female_2010', 'Male_2010', 'Both sexes_2013', 'Female_2013',
       'Male_2013', 'Both sexes_2014', 'Female_2014', 'Male_2014',
       'Both sexes_2015', 'Female_2015', 'Male_2015', 'Both sexes_2016',
       'Female_2016', 'Male_2016', 'Both sexes_2017', 'Female_2017',
       'Male_2017', 'Both sexes_2018', 'Female_2018', 'Male_2018'],axis=1)

# %%
funBS = fun.copy()
funBS["Both sexes"] = fun[['Both sexes_2000',
'Both sexes_2005',
'Both sexes_2010',
'Both sexes_2013',
'Both sexes_2014',
'Both sexes_2015',
'Both sexes_2016',
'Both sexes_2017',
'Both sexes_2018']].mean(axis=1)
funBS.drop(['Both sexes_2000', 'Female_2000', 'Male_2000',
       'Both sexes_2005', 'Female_2005', 'Male_2005', 'Both sexes_2010',
       'Female_2010', 'Male_2010', 'Both sexes_2013', 'Female_2013',
       'Male_2013', 'Both sexes_2014', 'Female_2014', 'Male_2014',
       'Both sexes_2015', 'Female_2015', 'Male_2015', 'Both sexes_2016',
       'Female_2016', 'Male_2016', 'Both sexes_2017', 'Female_2017',
       'Male_2017', 'Both sexes_2018', 'Female_2018', 'Male_2018'],axis=1,inplace=True)

# %%
funM = fun.copy()
funM["Male"] = fun[['Male_2000',
'Male_2005',
'Male_2010',
'Male_2013',
'Male_2014',
'Male_2015',
'Male_2016',
'Male_2017',
'Male_2018']].mean(axis=1)
funM.drop(['Both sexes_2000', 'Female_2000', 'Male_2000',
       'Both sexes_2005', 'Female_2005', 'Male_2005', 'Both sexes_2010',
       'Female_2010', 'Male_2010', 'Both sexes_2013', 'Female_2013',
       'Male_2013', 'Both sexes_2014', 'Female_2014', 'Male_2014',
       'Both sexes_2015', 'Female_2015', 'Male_2015', 'Both sexes_2016',
       'Female_2016', 'Male_2016', 'Both sexes_2017', 'Female_2017',
       'Male_2017', 'Both sexes_2018', 'Female_2018', 'Male_2018'],axis=1,inplace=True)

# %%
funF = fun.copy()
funF["Male"] = fun[['Female_2000',
'Female_2005',
'Female_2010',
'Female_2013',
'Female_2014',
'Female_2015',
'Female_2016',
'Female_2017',
'Female_2018']].mean(axis=1)
funF.drop(['Both sexes_2000', 'Female_2000', 'Male_2000',
       'Both sexes_2005', 'Female_2005', 'Male_2005', 'Both sexes_2010',
       'Female_2010', 'Male_2010', 'Both sexes_2013', 'Female_2013',
       'Male_2013', 'Both sexes_2014', 'Female_2014', 'Male_2014',
       'Both sexes_2015', 'Female_2015', 'Male_2015', 'Both sexes_2016',
       'Female_2016', 'Male_2016', 'Both sexes_2017', 'Female_2017',
       'Male_2017', 'Both sexes_2018', 'Female_2018', 'Male_2018'],axis=1,inplace=True)

# %%
funF
# Out:
#     Code  EnforceBansTobaccoAd_2007  EnforceBansTobaccoAd_2010  \
# 0    ARM                        2.0                        2.0
# 1    AUS                        4.0                        4.0
# 2    AUT                        4.0                        4.0
# 3    AZE                        4.0                        4.0
# 4    BEL                        4.0                        4.0
# ..   ...                        ...                        ...
# 174  BMU                        NaN                        NaN
# 175  GRL                        NaN                        NaN
# 176  GUM                        NaN                        NaN
# 177  PRI                        NaN                        NaN
# 178  TWN                        NaN                        NaN
#
#      EnforceBansTobaccoAd_2012  EnforceBansTobaccoAd_2014  HelpToQuit_2007  \
# 0                          2.0                        2.0              3.0
# ...

# %%
funDR.set_index("Code",inplace=True)

# %%
from sklearn.impute import SimpleImputer

# %%
funDR.drop(['NATL_Country', 'NATL_Region'],axis=1,inplace=True)

# %%
funDR = pd.get_dummies(funDR,columns=["EnforceBansTobaccoAd_2007","EnforceBansTobaccoAd_2010",
"EnforceBansTobaccoAd_2012",
"EnforceBansTobaccoAd_2014",
"HelpToQuit_2007",
"HelpToQuit_2010",
"HelpToQuit_2012",
"HelpToQuit_2014",
"EnforceBansTobaccoAd_2016"])

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

imputer = imputer.fit(funDR)

# %%
imputed = imputer.transform(funDR)

# %%
funDRImputed = pd.DataFrame(imputed, index = funDR.index, columns=funDR.columns)

# %%
PCA
# Out:
# sklearn.decomposition._pca.PCA

# %%
funDRImputedFeatures = funDRImputed.drop("deathRate_avg",axis=1)

# %%
funDRImputedTarget = funDRImputed["deathRate_avg"]

# %%
from sklearn import linear_model

reg = linear_model.Lasso(alpha=0.1)
reg.fit(funDRImputedFeatures,funDRImputedTarget)
# Out:
# Lasso(alpha=0.1)

# %%
list(reg.coef_)
# Out:
# [-3.4356627292787326e-08,
#  4.577835615880582e-06,
#  -0.007488925905295242,
#  0.0724361594185142,
#  -0.0920238245930859,
#  -0.28855916077828947,
#  -0.0012072098319693462,
#  0.39443270167265804,
#  0.08786109654261162,
#  1.139975913773525,
#  -0.5387282922165078,
#  -0.0,
#  16.835878292343267,
#  -1.7493228957713345,
#  3.6238320783726437,
#  20.848099370573625,
#  -0.0,
#  -9.107702511405204,
#  -0.4352541262164643,
#  0.4568365439598333,
#  -0.0,
#  -0.0,
#  3.143902803697941,
#  5.253289201657123,
#  -16.914642136912864,
#  3.776620413325916,
#  5.608376392811392,
#  41.36892699928971,
#  7.550113656203845,
#  -13.279629021274586,
#  -34.51444629966918,
#  2.2539612741333346,
#  5.513317011439562,
#  8.747258320642434,
#  0.0,
#  -19.89041849918071,
#  9.315522226450478,
#  -13.905665691234608,
#  0.0,
#  29.26217396517787,
#  0.0,
#  17.15523871911608,
#  0.0,
#  -6.345531998643872,
#  0.0,
#  -0.0,
#  0.0,
#  0.0,
#  0.705392385961629,
#  2.7420228821888064,
#  0.0,
# ...

# %%
from sklearn.decomposition import PCA

# %%
funDR_PCA = PCA(n_components=5)

# %%
funDR_PCA.fit(funDRImputedFeatures)
# Out:
# PCA(n_components=5)

# %%
print(list(funDR_PCA.explained_variance_ratio_))
# Out:
# [0.999821311691473, 0.00017868221102625153, 6.002254746382852e-09, 9.454910702612737e-11, 5.245421380370366e-13]

# %%
print(list(funDR_PCA.components_[0]))
# Out:
# [0.9999758573356016, 0.006948722159907633, -1.7721768154026257e-07, -2.2757371993367e-08, 5.06038883131606e-10, -4.0154724213886933e-10, -2.498021054894557e-06, -4.917613364711466e-09, 7.657039528422304e-09, 1.9380708532690695e-08, -3.945466016983802e-09, -1.5433735246195724e-08, -9.675568807306263e-11, -5.975155430875861e-09, -1.9339584953278115e-09, -2.7681363751099196e-11, 8.62294918913243e-11, -5.719212072318345e-11, -1.38876640149946e-09, -7.743528210938496e-09, -2.9850100219307093e-10, 7.1064318867500145e-12, 3.8391541074139886e-10, -3.3204910064163634e-11, -1.6143040373502782e-10, 3.2987438017810014e-10, -1.0912804607215781e-10, -1.1614853007798899e-10, 2.4931892463149925e-10, -7.385446418259613e-11, -1.4247552828170353e-10, 2.9079349356277197e-10, -8.9002034910154e-11, -1.8479952789389442e-10, 4.541943280322822e-10, -2.1430648201317808e-10, 4.227612245704475e-12, -1.3311346872324922e-10, 4.23483810779437e-10, -3.047100218466742e-10, 7.365561016140068e-11, -1.1433768760835901e
# ...

# %%
funDR_PCA.singular_values_
# Out:
# array([1.76007884e+09, 2.35294397e+07, 1.36372920e+05, 1.71158961e+04,
#        1.27485596e+03])

# %%
funDR_PCA.explained_variance_ratio_
# Out:
# array([9.99821312e-01, 1.78682211e-04, 6.00225475e-09, 9.45491070e-11,
#        5.24542138e-13])

# %%
import statsmodels.api as sm

# %%
results =sm.OLS(funDRImputedTarget,funDRImputedFeatures).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          deathRate_avg   R-squared (uncentered):                   0.926
# Model:                            OLS   Adj. R-squared (uncentered):              0.901
# Method:                 Least Squares   F-statistic:                              37.14
# Date:                Sat, 20 Nov 2021   Prob (F-statistic):                    8.39e-57
# Time:                        15:48:04   Log-Likelihood:                         -862.11
# No. Observations:                 179   AIC:                                      1814.
# Df Residuals:                     134   BIC:                                      1958.
# Df Model:                          45
# Covariance Type:            nonrobust
# ...
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
import statsmodels.multivariate.factor as factor

# %%
funDRImputedFeaturesFactor =factor.Factor(funDRImputedFeatures,n_factor=2)

# %%
res = funDRImputedFeaturesFactor.fit()

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Factor analysis results
# ...

# %%
from statsmodels.multivariate import manova as manova

# %%
manovaDR = manova.MANOVA(funDRImputedFeatures,funDRImputedTarget)

# %%
manovaDR.mv_test().summary()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                    Multivariate linear model
# ...
#
# ----------------------------------------------------------------
#            x0            Value  Num DF  Den DF   F Value  Pr > F
# ----------------------------------------------------------------
#           Wilks' lambda -0.1818 9.0000 170.0000 -122.8002 1.0000
#          Pillai's trace  8.8108 9.0000 170.0000  -21.3072 1.0000
#  Hotelling-Lawley trace 12.3525 9.0000 170.0000  233.3249 0.0000
#     Roy's greatest root 12.4714 9.0000 170.0000  235.5703 0.0000
# ...
#
# """
