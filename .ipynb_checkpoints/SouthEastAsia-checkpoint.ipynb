# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns

# %%
tobacco_use_ww = pd.read_csv("Data/tobacco_use_ww.csv")

# %%
tobbacco_production = pd.read_csv("Data/tobacco_production.csv")

# %%
stop_smoking = pd.read_csv("Data/stop_smoking.csv")

# %%
sales_per_day = pd.read_csv("Data/sales_per_day.csv")

# %%
death_rates_smoking_age = pd.read_csv("Data/death_rates_smoking_age.csv")

# %%
tobacco_use_ww["Location"].unique()
# Out:
# array(["Democratic People's Republic of Korea", 'Azerbaijan', 'Eritrea',
#        'Egypt', 'Ghana', 'Nigeria', 'Oman', 'Senegal', 'Niger',
#        'United Arab Emirates', 'Ethiopia', 'Morocco', 'Malaysia',
#        'Cameroon', 'Qatar', 'Uzbekistan', 'Zimbabwe', 'Algeria',
#        'Sao Tome and Principe', 'Gambia', 'Armenia', 'Côte d’Ivoire',
#        'Togo', 'Mali', 'China', 'Liberia', 'Benin', 'Botswana', 'Belarus',
#        'Japan', 'Eswatini', 'Timor-Leste', 'Bahamas', 'Jamaica',
#        'Madagascar', 'Fiji', 'Panama', 'Dominican Republic', 'Palau',
#        'Brazil', 'Chad', 'Kenya', 'India', 'Tonga', 'Colombia', 'Guyana',
#        'Canada', 'Burundi', 'El Salvador', 'Malawi', 'Paraguay', 'Haiti',
#        'Rwanda', 'United Republic of Tanzania', 'New Zealand',
#        'Australia', 'Iceland', 'Mexico', 'Iran (Islamic Republic of)',
#        'Mozambique', 'Cuba', 'Costa Rica', 'Zambia', 'Barbados', 'Nepal',
#        'Argentina', 'Brunei Darussalam',
#        "Lao People's Democratic Republic", 'Uganda', 'Peru',
#        'Russian Federation', 'Israel', 'Romania', 'Burkina Faso',
#        'South Africa', 'Congo', 'Singapore', 'Saudi Arabia', 'Samoa',
#        'Turkey', 'United Kingdom of Great Britain and Northern Ireland',
#        'Bangladesh', 'Norway', 'Namibia', 'Finland', 'Denmark', 'Uruguay',
#        'Lithuania', 'United States of America', 'Comoros', 'Italy',
#        'Luxembourg', 'Sierra Leone', 'Solomon Islands', 'Sri Lanka',
#        'Tunisia', 'Pakistan', 'Slovenia', 'Myanmar', 'Yemen',
#        'Seychelles', 'Ireland', 'Netherlands', 'Poland', 'Cambodia',
#        'Cook Islands', 'Republic of Korea', 'Kuwait', 'Iraq', 'Portugal',
#        'Malta', 'Switzerland', 'Thailand', 'Belgium', 'Cyprus', 'Latvia',
#        'Estonia', 'Vanuatu', 'Philippines', 'Kazakhstan', 'Bahrain',
#        'Republic of Moldova', 'Ukraine', 'Germany', 'Slovakia', 'Hungary',
#        'Spain', 'Mauritius', 'Czechia', 'Mongolia', 'Austria',
#        'Kyrgyzstan', 'Sweden', 'Albania', 'Andorra', 'Georgia', 'Lesotho',
#        'Bosnia and Herzegovina', 'Tuvalu', 'Greece', 'France', 'Bulgaria',
#        'Croatia', 'Kiribati', 'Lebanon', 'Indonesia', 'Serbia', 'Chile',
#        'Nauru'], dtype=object)

# %%
tobacco_use_ww.head()
# Out:
#   ParentLocationCode         ParentLocation SpatialDimValueCode  \
# 0               SEAR        South-East Asia                 PRK
# 1                EUR                 Europe                 AZE
# 2                AFR                 Africa                 ERI
# 3                EMR  Eastern Mediterranean                 EGY
# 4                AFR                 Africa                 GHA
#
#                                 Location  Year  Gender  Value
# 0  Democratic People's Republic of Korea  2018  Female    0.0
# 1                             Azerbaijan  2018  Female    0.2
# 2                                Eritrea  2018  Female    0.3
# 3                                  Egypt  2018  Female    0.4
# 4                                  Ghana  2018  Female    0.4

# %%
SEA_Countries = tobacco_use_ww[tobacco_use_ww["ParentLocation"]=="South-East Asia"]["Location"].unique()[1:]

# %%
SEA_Countries_Code = tobacco_use_ww[tobacco_use_ww["ParentLocation"]=="South-East Asia"]["SpatialDimValueCode"].unique()[1:]

# %%
SEA_Countries[1:]
# Out:
# array(['India', 'Nepal', 'Bangladesh', 'Sri Lanka', 'Myanmar', 'Thailand',
#        'Indonesia'], dtype=object)

# %%
SEA_Countries_Code
# Out:
# array(['TLS', 'IND', 'NPL', 'BGD', 'LKA', 'MMR', 'THA', 'IDN'],
#       dtype=object)

# %%
SEAtobacco_use = tobacco_use_ww[tobacco_use_ww["ParentLocation"]=="South-East Asia"]

# %%
SEAdeath_rates_smoking_age = death_rates_smoking_age[death_rates_smoking_age["Code"].isin(SEA_Countries_Code)]

# %%
SEAdeath_rates_smoking_age = SEAdeath_rates_smoking_age.set_index(["Entity","Year"])

# %%
SEAdeath_rates_smoking_age
# Out:
#                 Code   All_ages  Under_5  5_14       50_69      15_49  \
# Entity     Year
# Bangladesh 1990  BGD  65.196925      NaN   NaN  423.300862  15.208375
#            1991  BGD  59.622708      NaN   NaN  385.099148  14.707365
#            1992  BGD  58.434904      NaN   NaN  379.997296  14.430231
#            1993  BGD  56.694899      NaN   NaN  370.225044  13.979145
#            1994  BGD  55.169681      NaN   NaN  360.865650  13.617300
# ...              ...        ...      ...   ...         ...        ...
# Timor      2013  TLS  59.917226      NaN   NaN  280.517954   9.872944
#            2014  TLS  60.909001      NaN   NaN  281.193937  10.047277
#            2015  TLS  61.748025      NaN   NaN  282.294311  10.140935
#            2016  TLS  62.155053      NaN   NaN  283.266170  10.200370
#            2017  TLS  62.531800      NaN   NaN  284.202569  10.204706
#
#                      70_plus
# Entity     Year
# Bangladesh 1990  1343.098324
#            1991  1252.874838
#            1992  1242.360959
#            1993  1215.737666
#            1994  1187.850110
# ...                      ...
# Timor      2013   998.524177
#            2014   992.366101
#            2015   961.923909
#            2016   931.201418
#            2017   913.538111
#
# [224 rows x 7 columns]

# %%
vals = SEAdeath_rates_smoking_age.values.reshape(len(SEAdeath_rates_smoking_age.index.levels[0]),len(SEAdeath_rates_smoking_age.index.levels[1]),-1)

# %%
import itertools

# %%
SEAdeath_rates_smoking_ageRest = pd.DataFrame(vals[:,:,1:].reshape(len(SEAdeath_rates_smoking_age.index.levels[0]),-1),
             columns=pd.MultiIndex.from_product([SEAdeath_rates_smoking_age.index.levels[1],SEAdeath_rates_smoking_age.columns[1:]]))

# %%
SEAdeath_rates_smoking_ageRest["Code"] = SEAdeath_rates_smoking_age.index.levels[0]

# %%
SEAdeath_rates_smoking_ageRest.set_index("Code")
# Out:
# Year             1990                                                   \
#              All_ages Under_5 5_14       50_69      15_49      70_plus
# Code
# Bangladesh  65.196925     NaN  NaN  423.300862  15.208375  1343.098324
# India       74.678606     0.0  0.0  374.532083  20.050705  1283.416056
# Indonesia    57.51076     0.0  0.0  284.579656  19.505391    942.17639
# Myanmar     174.93985     NaN  NaN  794.832187  39.881585   2995.58712
# Nepal       79.896754     NaN  NaN  434.501462  18.025562  1692.540237
# Sri Lanka   67.114661     NaN  NaN  268.498075   14.82635  1030.277712
# Thailand    78.424831     NaN  NaN  303.746179  17.083926  1232.773733
# Timor       45.478902     NaN  NaN  321.838354  19.732101  1178.659194
#
# Year              1991                           ... 2016              \
#               All_ages Under_5 5_14       50_69  ... 5_14       50_69
# Code                                             ...
# Bangladesh   59.622708     NaN  NaN  385.099148  ...  NaN    201.4439
# India        75.247144     0.0  0.0  374.234549  ...  0.0  218.987784
# Indonesia    58.371788     0.0  0.0  285.258956  ...  0.0  285.469425
# Myanmar     174.373789     NaN  NaN  788.007735  ...  NaN  342.101828
# Nepal        78.780786     NaN  NaN  425.525221  ...  NaN  265.469462
# Sri Lanka    62.527944     NaN  NaN  244.633878  ...  NaN  130.816245
# Thailand     80.084579     NaN  NaN  302.554076  ...  NaN  132.054288
# Timor        45.481587     NaN  NaN  324.146417  ...  NaN   283.26617
#
# Year                                      2017                           \
#                 15_49      70_plus    All_ages Under_5 5_14       50_69
# Code
# Bangladesh   8.554756   670.976404   57.838244     NaN  NaN  201.428497
# India       11.550954   820.651098   64.783225     0.0  0.0  212.635824
# Indonesia   20.413249    995.62683   88.123544     0.0  0.0  282.233267
# Myanmar     15.024143  1884.356718  128.974071     NaN  NaN  334.615218
# Nepal        7.019913   1272.42408   78.811239     NaN  NaN  259.568449
# Sri Lanka    6.816241   542.172598   58.754563     NaN  NaN  127.843147
# Thailand    13.601378   573.369726   79.623311     NaN  NaN  129.585486
# Timor        10.20037   931.201418     62.5318     NaN  NaN  284.202569
#
# Year
#                 15_49      70_plus
# Code
# Bangladesh   8.301123   688.514029
# India       11.160558   804.536699
# Indonesia    19.98239   980.013163
# Myanmar     14.451101  1841.808359
# Nepal        6.719342   1249.53251
# Sri Lanka    6.602163   519.789173
# Thailand    13.264916   564.533264
# Timor       10.204706   913.538111
#
# [8 rows x 168 columns]

# %%
SEAdeath_rates_smoking_ageRest.columns = SEAdeath_rates_smoking_ageRest.columns.swaplevel(0, 1)

# %%
SEAdeath_rates_smoking_ageRest = SEAdeath_rates_smoking_ageRest.drop(["Under_5","5_14"],axis=1)
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\pandas\core\generic.py:4150: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %%
SEAdeath_rates_smoking_ageRest.set_index(("","Code"))
# Out:
#              All_ages       50_69      15_49      70_plus    All_ages  \
# Year             1990        1990       1990         1990        1991
# (, Code)
# Bangladesh  65.196925  423.300862  15.208375  1343.098324   59.622708
# India       74.678606  374.532083  20.050705  1283.416056   75.247144
# Indonesia    57.51076  284.579656  19.505391    942.17639   58.371788
# Myanmar     174.93985  794.832187  39.881585   2995.58712  174.373789
# Nepal       79.896754  434.501462  18.025562  1692.540237   78.780786
# Sri Lanka   67.114661  268.498075   14.82635  1030.277712   62.527944
# Thailand    78.424831  303.746179  17.083926  1232.773733   80.084579
# Timor       45.478902  321.838354  19.732101  1178.659194   45.481587
#
#                  50_69      15_49      70_plus    All_ages       50_69  ...  \
# Year              1991       1991         1991        1992        1992  ...
# (, Code)                                                                ...
# Bangladesh  385.099148  14.707365  1252.874838   58.434904  379.997296  ...
# India       374.234549  19.858827  1286.267683   75.157275  371.460697  ...
# Indonesia   285.258956  19.271579   942.920143   59.381841   286.72709  ...
# Myanmar     788.007735   39.36375   2959.43637  173.314239  778.524812  ...
# Nepal       425.525221  17.479702  1658.889698   77.147052  412.937398  ...
# Sri Lanka   244.633878  13.160121   962.851512   62.385711  241.102617  ...
# Thailand    302.554076  17.625799  1232.478098   81.004765  295.758329  ...
# Timor       324.146417  19.379159   1164.57946   45.523131  326.315958  ...
#
#                 15_49      70_plus    All_ages       50_69      15_49  \
# Year             2015         2015        2016        2016       2016
# (, Code)
# Bangladesh   8.761821   677.569882   55.523789    201.4439   8.554756
# India       11.754335   823.804517   65.216414  218.987784  11.550954
# Indonesia   20.869031  1004.961262   87.633829  285.469425  20.413249
# Myanmar     15.674533  1919.561904  129.292348  342.101828  15.024143
# Nepal        7.284227  1294.004315   78.896267  265.469462   7.019913
# Sri Lanka    7.057734   567.273017   59.122684  130.816245   6.816241
# Thailand    13.456297   577.372643   78.457963  132.054288  13.601378
# Timor       10.140935   961.923909   62.155053   283.26617   10.20037
#
#                 70_plus    All_ages       50_69      15_49      70_plus
# Year               2016        2017        2017       2017         2017
# (, Code)
# Bangladesh   670.976404   57.838244  201.428497   8.301123   688.514029
# India        820.651098   64.783225  212.635824  11.160558   804.536699
# Indonesia     995.62683   88.123544  282.233267   19.98239   980.013163
# Myanmar     1884.356718  128.974071  334.615218  14.451101  1841.808359
# Nepal        1272.42408   78.811239  259.568449   6.719342   1249.53251
# Sri Lanka    542.172598   58.754563  127.843147   6.602163   519.789173
# Thailand     573.369726   79.623311  129.585486  13.264916   564.533264
# Timor        931.201418     62.5318  284.202569  10.204706   913.538111
#
# [8 rows x 112 columns]

# %%
death_rates_smoking_age[death_rates_smoking_age["Code"].isin(SEA_Countries_Code)]["Code"].unique()
# Out:
# array(['BGD', 'IND', 'IDN', 'MMR', 'NPL', 'LKA', 'THA', 'TLS'],
#       dtype=object)

# %%
tobbacco_production[tobbacco_production["Country or Area"].isin(SEA_Countries)]["Country or Area"].unique()
# Out:
# array(['Bangladesh', 'India', 'Indonesia', 'Nepal', 'Thailand'],
#       dtype=object)

# %%
array(['India', 'Nepal', 'Bangladesh', 'Sri Lanka', 'Myanmar', 'Thailand',
       'Indonesia'], dtype=object)

# %%
tobbacco_production["Country or Area"].unique()
# Out:
# array(['Albania', 'Algeria', 'Australia', 'Austria', 'Azerbaijan',
#        'Bangladesh', 'Belgium', 'Bosnia and Herzegovina', 'Brazil',
#        'Bulgaria', 'Cabo Verde', 'Cambodia', 'Canada', 'China',
#        'China, Macao Special Administrative Region', 'Colombia',
#        'Croatia', 'Cuba', 'Cyprus', 'Denmark', 'Ecuador', 'Egypt',
#        'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary',
#        'Iceland', 'India', 'Indonesia', 'Iran (Islamic Republic of)',
#        'Ireland', 'Italy', 'Japan', 'Kazakhstan', 'Kenya', 'Kyrgyzstan',
#        "Lao People's Democratic Republic", 'Latvia', 'Lebanon',
#        'Lithuania', 'Luxembourg', 'Madagascar', 'Malawi', 'Malta',
#        'Mexico', 'Mongolia', 'Montenegro', 'Morocco', 'Mozambique',
#        'Nepal', 'Netherlands', 'New Zealand', 'Nigeria', 'Norway',
#        'Poland', 'Portugal', 'Republic of Moldova', 'Romania',
#        'Russian Federation', 'Serbia', 'Slovakia', 'Slovenia',
#        'South Africa', 'Sweden', 'Switzerland', 'Syrian Arab Republic',
#        'Thailand', 'The former Yugoslav Republic of Macedonia', 'Tunisia',
#        'Turkey', 'Ukraine', 'United Kingdom',
#        'United Republic of Tanzania', 'United States of America',
#        'Uruguay', 'Uzbekistan', 'Viet Nam'], dtype=object)

# %%
stop_smoking[stop_smoking["Code"].isin(SEA_Countries_Code)]
# Out:
#          Entity Code  Year  AvgCigarettePriceDollars  \
# 13   Bangladesh  BGD  2012                      1.38
# 14   Bangladesh  BGD  2014                      1.54
# 83        India  IND  2012                      5.33
# 84        India  IND  2014                      4.63
# 85    Indonesia  IDN  2012                      2.20
# 86    Indonesia  IDN  2014                      2.68
# 121       Nepal  NPL  2012                      1.78
# 122       Nepal  NPL  2014                      1.73
# 172   Sri Lanka  LKA  2012                      7.63
# 173   Sri Lanka  LKA  2014                      8.42
# 178    Thailand  THA  2012                      2.94
# 179    Thailand  THA  2014                      3.41
# 248  Bangladesh  BGD  2007                       NaN
# 249  Bangladesh  BGD  2010                       NaN
# 434       India  IND  2007                       NaN
# 435       India  IND  2010                       NaN
# 436   Indonesia  IDN  2007                       NaN
# 437   Indonesia  IDN  2010                       NaN
# 555     Myanmar  MMR  2007                       NaN
# 556     Myanmar  MMR  2010                       NaN
# 557     Myanmar  MMR  2012                       NaN
# 558     Myanmar  MMR  2014                       NaN
# 567       Nepal  NPL  2007                       NaN
# 568       Nepal  NPL  2010                       NaN
# 690   Sri Lanka  LKA  2007                       NaN
# 691   Sri Lanka  LKA  2010                       NaN
# 716    Thailand  THA  2007                       NaN
# 717    Thailand  THA  2010                       NaN
# 718       Timor  TLS  2007                       NaN
# 719       Timor  TLS  2010                       NaN
# 720       Timor  TLS  2012                       NaN
# 721       Timor  TLS  2014                       NaN
#
#      AvgTaxesAsPctCigarettePrice  EnforceBansTobaccoAd  HelpToQuit
# 13                          63.8                     4           3
# 14                          75.6                     4           3
# 83                          33.2                     4           4
# 84                          66.1                     4           4
# 85                          35.5                     2           3
# 86                          50.8                     2           3
# 121                         32.9                     4           3
# 122                         46.6                     5           3
# 172                         74.2                     4           3
# 173                         73.5                     4           3
# 178                         68.7                     4           4
# 179                         70.2                     4           4
# 248                          NaN                     4           3
# 249                          NaN                     4           3
# 434                          NaN                     4           3
# 435                          NaN                     4           3
# 436                          NaN                     2           3
# 437                          NaN                     2           3
# 555                          NaN                     4           3
# 556                          NaN                     4           3
# 557                          NaN                     4           3
# 558                          NaN                     4           4
# 567                          NaN                     2           2
# 568                          NaN                     4           4
# 690                          NaN                     4           3
# 691                          NaN                     4           3
# 716                          NaN                     4           4
# 717                          NaN                     4           4
# 718                          NaN                     2           2
# 719                          NaN                     2           2
# 720                          NaN                     2           2
# 721                          NaN                     2           2
