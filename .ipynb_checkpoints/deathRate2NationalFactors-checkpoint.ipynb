# %%
import pandas as pd
import seaborn as sns 
import numpy as np

# %%
countries = pd.read_pickle("Data/countriesData.pkl")

# %%
death_rates_smoking_age = pd.read_csv("Data/death_rates_smoking_age.csv")

# %%
countries
# Out:
#     Code  NATL_Surface area (km2)  NATL_Population in thousands (2017)  \
# 0    AFG                 652864.0                              35530.0
# 1    ALB                  28748.0                               2930.0
# 2    DZA                2381741.0                              41318.0
# 3    ASM                    199.0                                 56.0
# 4    AND                    468.0                                 77.0
# ..   ...                      ...                                  ...
# 224                         142.0                                 12.0
# 225                      266000.0                                553.0
# 226  YEM                 527968.0                              28250.0
# 227  ZMB                 752612.0                              17094.0
# 228  ZWE                 390757.0                              16530.0
#
#      NATL_Population density (per km2, 2017)  \
# 0                                       54.4
# 1                                      106.9
# 2                                       17.3
# 3                                      278.2
# 4                                      163.8
# ..                                       ...
# 224                                     84.1
# 225                                      2.1
# 226                                     53.5
# 227                                     23.0
# 228                                     42.7
#
#      NATL_Sex ratio (m per 100 f, 2017)  \
# 0                                 106.3
# 1                                 101.9
# 2                                 102.0
# 3                                 103.6
# 4                                 102.3
# ..                                  ...
# 224                                93.4
# 225                               110.1
# 226                               102.1
# 227                                98.5
# 228                                95.0
#
#      NATL_GDP: Gross domestic product (million current US$)  \
# 0                                              20270.0
# 1                                              11541.0
# 2                                             164779.0
# 3                                                  NaN
# 4                                               2812.0
# ..                                                 ...
# 224                                                NaN
# 225                                                NaN
# 226                                            29688.0
# 227                                            21255.0
# 228                                            13893.0
#
#      NATL_GDP growth rate (annual %, const. 2005 prices)  \
# 0                                                 -2.4
# 1                                                  2.6
# 2                                                  3.8
# 3                                                  NaN
# 4                                                  0.8
# ..                                                 ...
# 224                                                NaN
# 225                                                NaN
# 226                                              -28.1
# 227                                                2.9
# 228                                                1.1
#
#      NATL_GDP per capita (current US$)  NATL_Economy: Agriculture (% of GVA)  \
# 0                                623.2                                  23.3
# 1                               3984.2                                  22.4
# 2                               4154.1                                  12.2
# 3                                  NaN                                   NaN
# 4                              39896.4                                   0.5
# ..                                 ...                                   ...
# 224                                NaN                                   NaN
# 225                                NaN                                   NaN
# 226                             1106.4                                  14.7
# 227                             1311.1                                   8.2
# 228                              890.4                                  13.0
#
#      NATL_Economy: Industry (% of GVA)  ...  NATL_Threatened species (number)  \
# 0                                 23.3  ...                               2.1
# 1                                 26.0  ...                              28.2
# 2                                 37.3  ...                               0.8
# 3                                  NaN  ...                              87.9
# 4                                 10.8  ...                              34.0
# ..                                 ...  ...                               ...
# 224                                NaN  ...                              41.6
# 225                                NaN  ...                               2.7
# 226                               36.9  ...                               1.0
# 227                               32.3  ...                              65.6
# 228                               30.5  ...                              37.2
#
#      NATL_Forested area (% of land area)  \
# 0                              32.666667
# 1                               2.850000
# 2                              39.297297
# 3                                    NaN
# 4                               0.078125
# ..                                   ...
# 224                             0.000000
# 225                                  NaN
# 226                            25.222222
# 227                            15.000000
# 228                            15.000000
#
#      NATL_CO2 emission estimates (million tons/tons per capita)  \
# 0                                                 63.0
# 1                                                 84.0
# 2                                               5900.0
# 3                                                  NaN
# 4                                                  1.0
# ..                                                 ...
# 224                                                NaN
# 225                                                NaN
# 226                                              668.0
# 227                                              374.0
# 228                                              482.0
#
#      NATL_Energy production, primary (Petajoules)  \
# 0                                             5.0
# 1                                            36.0
# 2                                            55.0
# 3                                             NaN
# 4                                           119.0
# ..                                            ...
# 224                                          26.0
# 225                                           NaN
# 226                                          12.0
# 227                                          26.0
# 228                                          30.0
#
#      NATL_Energy supply per capita (Gigajoules)  \
# 0                                      1.663830
# 1                                      0.996849
# 2                                      1.030562
# 3                                      1.000000
# 4                                      1.000000
# ..                                          ...
# 224                                         NaN
# 225                                         NaN
# 226                                    1.548387
# 227                                    1.668616
# 228                                    1.441308
#
#      NATL_Net Official Development Assist. received (% of GNI)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 224                                                NaN
# 225                                                NaN
# 226                                                NaN
# 227                                                NaN
# 228                                                NaN
#
#      NATL_Pop. using improved drinking water (urban %)  \
# 0                                                 45.1
# 1                                                 95.5
# 2                                                 89.8
# 3                                                 62.5
# 4                                                100.0
# ..                                                 ...
# 224                                                NaN
# 225                                                NaN
# 226                                               92.5
# 227                                               55.6
# 228                                               49.3
#
#      NATL_Pop. using improved drinking water (rural %)  \
# 0                                                 27.0
# 1                                                 90.2
# 2                                                 82.2
# 3                                                 62.5
# 4                                                100.0
# ..                                                 ...
# 224                                                NaN
# 225                                                NaN
# 226                                               34.1
# 227                                               35.7
# 228                                               30.8
#
#      NATL_Pop. using improved sanitation facilities (urban %)  \
# 0                                                21.43
# 1                                                 2.96
# 2                                                 0.05
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 224                                                NaN
# 225                                                NaN
# 226                                               2.99
# 227                                               3.96
# 228                                               6.00
#
#      NATL_Pop. using improved sanitation facilities (rural %)
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 224                                                NaN
# 225                                                NaN
# 226                                                NaN
# 227                                                NaN
# 228                                                NaN
#
# [229 rows x 51 columns]

# %%
import pickle

# %%
convCountry2Code = pickle.load(open("Data/countryToCode.pkl","rb"))

# %%
GDP["Country"] = GDP["Country"].str.strip()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1172/3784029288.py in <module>
# ----> 1 GDP["Country"] = GDP["Country"].str.strip()
#
# NameError: name 'GDP' is not defined

# %%
convCountry2Code.update({"Anguilla":"AIA"})

# %%
GDP["Code"] = GDP["Country"].apply(lambda x: convCountry2Code[x] if x in convCountry2Code else "")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1172/3550255411.py in <module>
# ----> 1 GDP["Code"] = GDP["Country"].apply(lambda x: convCountry2Code[x] if x in convCountry2Code else "")
#
# NameError: name 'GDP' is not defined

# %%
GDP = GDP[["Code","GDP ($ per capita)"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1172/389120723.py in <module>
# ----> 1 GDP = GDP[["Code","GDP ($ per capita)"]]
#
# NameError: name 'GDP' is not defined

# %%
death_rates_smoking_age = death_rates_smoking_age[["Code","Year","All_ages"]]

# %%
death_rates_smoking_age = death_rates_smoking_age.pivot_table("All_ages",["Code"],"Year")

# %%
death_rates_smoking_age["avg"]  = death_rates_smoking_age.mean(axis=1)

# %%
death_rates_smoking_age.columns = ["deathRate_"+str(x) for x in death_rates_smoking_age.columns]

# %%
A = GDP[["Code","GDP ($ per capita)"]].copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1172/805273126.py in <module>
# ----> 1 A = GDP[["Code","GDP ($ per capita)"]].copy()
#
# NameError: name 'GDP' is not defined

# %%
B = death_rates_smoking_age.reset_index()[["Code","deathRate_avg"]].copy()

# %%
cbd = pd.merge(B,A,how="inner")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1172/1636412838.py in <module>
# ----> 1 cbd = pd.merge(B,A,how="inner")
#
# NameError: name 'A' is not defined

# %%
cbd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1172/3985359788.py in <module>
# ----> 1 cbd
#
# NameError: name 'cbd' is not defined

# %%
sns.regplot(data=cbd,x ="GDP ($ per capita)", y= "deathRate_avg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1172/3727018005.py in <module>
# ----> 1 sns.regplot(data=cbd,x ="GDP ($ per capita)", y= "deathRate_avg")
#
# NameError: name 'cbd' is not defined

# %%
countries["Country"] =countries["Country"].str.strip()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\ProgramData\Miniconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Miniconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1172/1388676915.py in <module>
# ----> 1 countries["Country"] =countries["Country"].str.strip()
#
# C:\ProgramData\Miniconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# C:\ProgramData\Miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Country'

# %%
countries["Code"] = countries["Country"].apply(lambda x: convCountry2Code[x] if x in convCountry2Code else "")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\ProgramData\Miniconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Miniconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1172/883756051.py in <module>
# ----> 1 countries["Code"] = countries["Country"].apply(lambda x: convCountry2Code[x] if x in convCountry2Code else "")
#
# C:\ProgramData\Miniconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# C:\ProgramData\Miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Country'

# %%
from matplotlib import pyplot as plt

# %%
countries
# Out:
#     Code  NATL_Surface area (km2)  NATL_Population in thousands (2017)  \
# 0    AFG                 652864.0                              35530.0
# 1    ALB                  28748.0                               2930.0
# 2    DZA                2381741.0                              41318.0
# 3    ASM                    199.0                                 56.0
# 4    AND                    468.0                                 77.0
# ..   ...                      ...                                  ...
# 224                         142.0                                 12.0
# 225                      266000.0                                553.0
# 226  YEM                 527968.0                              28250.0
# 227  ZMB                 752612.0                              17094.0
# 228  ZWE                 390757.0                              16530.0
#
#      NATL_Population density (per km2, 2017)  \
# 0                                       54.4
# 1                                      106.9
# 2                                       17.3
# 3                                      278.2
# 4                                      163.8
# ..                                       ...
# 224                                     84.1
# 225                                      2.1
# 226                                     53.5
# 227                                     23.0
# 228                                     42.7
#
#      NATL_Sex ratio (m per 100 f, 2017)  \
# 0                                 106.3
# 1                                 101.9
# 2                                 102.0
# 3                                 103.6
# 4                                 102.3
# ..                                  ...
# 224                                93.4
# 225                               110.1
# 226                               102.1
# 227                                98.5
# 228                                95.0
#
#      NATL_GDP: Gross domestic product (million current US$)  \
# 0                                              20270.0
# 1                                              11541.0
# 2                                             164779.0
# 3                                                  NaN
# 4                                               2812.0
# ..                                                 ...
# 224                                                NaN
# 225                                                NaN
# 226                                            29688.0
# 227                                            21255.0
# 228                                            13893.0
#
#      NATL_GDP growth rate (annual %, const. 2005 prices)  \
# 0                                                 -2.4
# 1                                                  2.6
# 2                                                  3.8
# 3                                                  NaN
# 4                                                  0.8
# ..                                                 ...
# 224                                                NaN
# 225                                                NaN
# 226                                              -28.1
# 227                                                2.9
# 228                                                1.1
#
#      NATL_GDP per capita (current US$)  NATL_Economy: Agriculture (% of GVA)  \
# 0                                623.2                                  23.3
# 1                               3984.2                                  22.4
# 2                               4154.1                                  12.2
# 3                                  NaN                                   NaN
# 4                              39896.4                                   0.5
# ..                                 ...                                   ...
# 224                                NaN                                   NaN
# 225                                NaN                                   NaN
# 226                             1106.4                                  14.7
# 227                             1311.1                                   8.2
# 228                              890.4                                  13.0
#
#      NATL_Economy: Industry (% of GVA)  ...  NATL_Threatened species (number)  \
# 0                                 23.3  ...                               2.1
# 1                                 26.0  ...                              28.2
# 2                                 37.3  ...                               0.8
# 3                                  NaN  ...                              87.9
# 4                                 10.8  ...                              34.0
# ..                                 ...  ...                               ...
# 224                                NaN  ...                              41.6
# 225                                NaN  ...                               2.7
# 226                               36.9  ...                               1.0
# 227                               32.3  ...                              65.6
# 228                               30.5  ...                              37.2
#
#      NATL_Forested area (% of land area)  \
# 0                              32.666667
# 1                               2.850000
# 2                              39.297297
# 3                                    NaN
# 4                               0.078125
# ..                                   ...
# 224                             0.000000
# 225                                  NaN
# 226                            25.222222
# 227                            15.000000
# 228                            15.000000
#
#      NATL_CO2 emission estimates (million tons/tons per capita)  \
# 0                                                 63.0
# 1                                                 84.0
# 2                                               5900.0
# 3                                                  NaN
# 4                                                  1.0
# ..                                                 ...
# 224                                                NaN
# 225                                                NaN
# 226                                              668.0
# 227                                              374.0
# 228                                              482.0
#
#      NATL_Energy production, primary (Petajoules)  \
# 0                                             5.0
# 1                                            36.0
# 2                                            55.0
# 3                                             NaN
# 4                                           119.0
# ..                                            ...
# 224                                          26.0
# 225                                           NaN
# 226                                          12.0
# 227                                          26.0
# 228                                          30.0
#
#      NATL_Energy supply per capita (Gigajoules)  \
# 0                                      1.663830
# 1                                      0.996849
# 2                                      1.030562
# 3                                      1.000000
# 4                                      1.000000
# ..                                          ...
# 224                                         NaN
# 225                                         NaN
# 226                                    1.548387
# 227                                    1.668616
# 228                                    1.441308
#
#      NATL_Net Official Development Assist. received (% of GNI)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 224                                                NaN
# 225                                                NaN
# 226                                                NaN
# 227                                                NaN
# 228                                                NaN
#
#      NATL_Pop. using improved drinking water (urban %)  \
# 0                                                 45.1
# 1                                                 95.5
# 2                                                 89.8
# 3                                                 62.5
# 4                                                100.0
# ..                                                 ...
# 224                                                NaN
# 225                                                NaN
# 226                                               92.5
# 227                                               55.6
# 228                                               49.3
#
#      NATL_Pop. using improved drinking water (rural %)  \
# 0                                                 27.0
# 1                                                 90.2
# 2                                                 82.2
# 3                                                 62.5
# 4                                                100.0
# ..                                                 ...
# 224                                                NaN
# 225                                                NaN
# 226                                               34.1
# 227                                               35.7
# 228                                               30.8
#
#      NATL_Pop. using improved sanitation facilities (urban %)  \
# 0                                                21.43
# 1                                                 2.96
# 2                                                 0.05
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 224                                                NaN
# 225                                                NaN
# 226                                               2.99
# 227                                               3.96
# 228                                               6.00
#
#      NATL_Pop. using improved sanitation facilities (rural %)
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 224                                                NaN
# 225                                                NaN
# 226                                                NaN
# 227                                                NaN
# 228                                                NaN
#
# [229 rows x 51 columns]

# %%
countries.columns[2:-1]
# Out:
# Index(['NATL_Population in thousands (2017)',
#        'NATL_Population density (per km2, 2017)',
#        'NATL_Sex ratio (m per 100 f, 2017)',
#        'NATL_GDP: Gross domestic product (million current US$)',
#        'NATL_GDP growth rate (annual %, const. 2005 prices)',
#        'NATL_GDP per capita (current US$)',
#        'NATL_Economy: Agriculture (% of GVA)',
#        'NATL_Economy: Industry (% of GVA)',
#        'NATL_Economy: Services and other activity (% of GVA)',
#        'NATL_Employment: Agriculture (% of employed)',
#        'NATL_Employment: Industry (% of employed)',
#        'NATL_Employment: Services (% of employed)',
#        'NATL_Unemployment (% of labour force)',
#        'NATL_Labour force participation (female/male pop. %)',
#        'NATL_Agricultural production index (2004-2006=100)',
#        'NATL_Food production index (2004-2006=100)',
#        'NATL_International trade: Exports (million US$)',
#        'NATL_International trade: Imports (million US$)',
#        'NATL_International trade: Balance (million US$)',
#        'NATL_Balance of payments, current account (million US$)',
#        'NATL_Population growth rate (average annual %)',
#        'NATL_Urban population (% of total population)',
#        'NATL_Urban population growth rate (average annual %)',
#        'NATL_Fertility rate, total (live births per woman)',
#        'NATL_Life expectancy at birth (females/males, years)',
#        'NATL_Population age distribution (0-14 / 60+ years, %)',
#        'NATL_International migrant stock (000/% of total pop.)',
#        'NATL_Refugees and others of concern to UNHCR (in thousands)',
#        'NATL_Infant mortality rate (per 1000 live births',
#        'NATL_Health: Total expenditure (% of GDP)',
#        'NATL_Health: Physicians (per 1000 pop.)',
#        'NATL_Education: Government expenditure (% of GDP)',
#        'NATL_Education: Primary gross enrol. ratio (f/m per 100 pop.)',
#        'NATL_Education: Secondary gross enrol. ratio (f/m per 100 pop.)',
#        'NATL_Education: Tertiary gross enrol. ratio (f/m per 100 pop.)',
#        'NATL_Seats held by women in national parliaments %',
#        'NATL_Mobile-cellular subscriptions (per 100 inhabitants)',
#        'NATL_Mobile-cellular subscriptions (per 100 inhabitants).1',
#        'NATL_Individuals using the Internet (per 100 inhabitants)',
#        'NATL_Threatened species (number)',
#        'NATL_Forested area (% of land area)',
#        'NATL_CO2 emission estimates (million tons/tons per capita)',
#        'NATL_Energy production, primary (Petajoules)',
#        'NATL_Energy supply per capita (Gigajoules)',
#        'NATL_Net Official Development Assist. received (% of GNI)',
#        'NATL_Pop. using improved drinking water (urban %)',
#        'NATL_Pop. using improved drinking water (rural %)',
#        'NATL_Pop. using improved sanitation facilities (urban %)'],
#       dtype='object')

# %%
from matplotlib import pyplot as plt

# %%
len(countries.columns[2:-1])
# Out:
# 48

# %%
48/6
# Out:
# 8.0

# %%
48/2
# Out:
# 24.0

# %%
48/2/4
# Out:
# 6.0

# %%
countries.drop(["NATL_Net Official Development Assist. received (% of GNI)"], axis=1,inplace= True)

# %%
len(countries.columns[2:-1])
# Out:
# 47

# %%
len(countries.columns[2:-24])
# Out:
# 24

# %%
countries.columns[-24:-1]
# Out:
# Index(['NATL_Life expectancy at birth (females/males, years)',
#        'NATL_Population age distribution (0-14 / 60+ years, %)',
#        'NATL_International migrant stock (000/% of total pop.)',
#        'NATL_Refugees and others of concern to UNHCR (in thousands)',
#        'NATL_Infant mortality rate (per 1000 live births',
#        'NATL_Health: Total expenditure (% of GDP)',
#        'NATL_Health: Physicians (per 1000 pop.)',
#        'NATL_Education: Government expenditure (% of GDP)',
#        'NATL_Education: Primary gross enrol. ratio (f/m per 100 pop.)',
#        'NATL_Education: Secondary gross enrol. ratio (f/m per 100 pop.)',
#        'NATL_Education: Tertiary gross enrol. ratio (f/m per 100 pop.)',
#        'NATL_Seats held by women in national parliaments %',
#        'NATL_Mobile-cellular subscriptions (per 100 inhabitants)',
#        'NATL_Mobile-cellular subscriptions (per 100 inhabitants).1',
#        'NATL_Individuals using the Internet (per 100 inhabitants)',
#        'NATL_Threatened species (number)',
#        'NATL_Forested area (% of land area)',
#        'NATL_CO2 emission estimates (million tons/tons per capita)',
#        'NATL_Energy production, primary (Petajoules)',
#        'NATL_Energy supply per capita (Gigajoules)',
#        'NATL_Pop. using improved drinking water (urban %)',
#        'NATL_Pop. using improved drinking water (rural %)',
#        'NATL_Pop. using improved sanitation facilities (urban %)'],
#       dtype='object')

# %%
fig,axs = plt.subplots(nrows=6,ncols=4, figsize=(40,50))
for ax,column in zip(axs.flatten(),countries.columns[2:-24]):
    A = countries[["Code",column]].copy()
    B = death_rates_smoking_age.reset_index()[["Code","deathRate_avg"]].copy()
    #print(A)
    #print(B)
    cbd = pd.merge(B,A,how="inner")
    #fig,ax = plt.subplots()
    
    sns.regplot(data=cbd,x =column, y= "deathRate_avg",ax = ax)
    ax.set_title("Factor: {x} to average death rate".format(x=column))
    plt.tight_layout()

fig.savefig("All_1.pdf")

# %%
fig,axs = plt.subplots(nrows=6,ncols=4, figsize=(40,50))
for ax,column in zip(axs.flatten(),countries.columns[-24:-1]):
    A = countries[["Code",column]].copy()
    B = death_rates_smoking_age.reset_index()[["Code","deathRate_avg"]].copy()
    #print(A)
    #print(B)
    cbd = pd.merge(B,A,how="inner")
    #fig,ax = plt.subplots()
    
    sns.regplot(data=cbd,x =column, y= "deathRate_avg",ax = ax)
    ax.set_title("Factor: {x} to average death rate".format(x=column))
    plt.tight_layout()
fig.savefig("All_2.pdf")

# %%
plt.savefig("gallery/Factor.{x} to average death rate.png".format(x=column.replace("%","").replace("/",".")))

# %%
a = pd.read_pickle("Data/allCombined.pkl")

# %%
a["Both sexes"] = a[['Both sexes_2000',
'Both sexes_2005',
'Both sexes_2010',
'Both sexes_2013',
'Both sexes_2014',
'Both sexes_2015',
'Both sexes_2016',
'Both sexes_2017',
'Both sexes_2018']].mean(axis=1)

# %%
a.reset_index()[["Code","Both sexes"]].copy()

# %%
fig,axs = plt.subplots(nrows=6,ncols=4, figsize=(40,50))
for ax,column in zip(axs.flatten(),countries.columns[2:-24]):
    A = countries[["Code",column]].copy()
    B = a.reset_index()[["Code","Both sexes"]].copy()
    cbd = pd.merge(B,A,how="inner")
    #fig,ax = plt.subplots()
    
    sns.regplot(data=cbd,x =column, y= "Both sexes",ax = ax)
    ax.set_title("Factor: {x} to consumption".format(x=column))
    plt.tight_layout()

#fig.savefig("All_1.pdf")

# %%
fig,axs = plt.subplots(nrows=6,ncols=4, figsize=(40,50))
for ax,column in zip(axs.flatten(),countries.columns[-24:-1]):
    A = countries[["Code",column]].copy()
    B = a.reset_index()[["Code","Both sexes"]].copy()
    cbd = pd.merge(B,A,how="inner")
    #fig,ax = plt.subplots()
    
    sns.regplot(data=cbd,x =column, y= "Both sexes",ax = ax)
    ax.set_title("Factor: {x} to consumption".format(x=column))
    plt.tight_layout()
fig.savefig("All_2.pdf")

# %%
plt.savefig("gallery/Factor.{x} to average death rate.png".format(x=column.replace("%","").replace("/",".")))
